# %% [markdown]
# <a href="https://colab.research.google.com/github/dejanbatanjac/tf/blob/master/make_blobs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs

plt.rcParams['figure.figsize'] = (16, 9)


# in case we need even the labels
X, y = make_blobs(n_samples=100, n_features=3, centers=4)


fig = plt.figure()

ax = Axes3D(fig)
ax.scatter(X[:, 0], X[:, 1], X[:, 2], c='blue')
plt.show()


# Initializing KMeans
kmeans = KMeans(n_clusters=4)
# Fitting with inputs
kmeans.fit(X)

# Predicting the clusters
labels = kmeans.predict(X)
# Getting the cluster centers
C = kmeans.cluster_centers_

fig = plt.figure()

ax = Axes3D(fig)
ax.scatter(X[:, 0], X[:, 1], X[:, 2], c='blue')
ax.scatter(C[:, 0], C[:, 1], C[:, 2], marker='+', c='red', s=1000)
plt.show()
